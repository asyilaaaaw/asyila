# %%
print("Nama: Asyila Wadda Nafi'ah")
#untuk menampilkan nama
print("NIM: 2605060004")
#untuk menampilkan NIM
print("Tempat, Tanggal Lahir: Kota Mgelang, 9 Juli 2008")
#untuk menampilkan tempat dan tanggal lahir
print("Alamat: Ngentak Kwayuhan, Jalan Abimanyu 3, RT 01/RW 02, Gelangan, Magelang Tengah, Kota Magelang")
#untuk menampilkan alamat
print("Jenis Kelamin: Perempuan")
#untuk menapilkan jenis kelamin
print("Hobi: Menulis, Menonton film, Membaca, Jalan-jalan menyusuri gang-gang cantik")
#untuk menampilkan hobi
# Out:
# Nama: Asyila Wadda Nafi'ah
# NIM: 2605060004
# Tempat, Tanggal Lahir: Kota Mgelang, 9 Juli 2008
# Alamat: Ngentak Kwayuhan, Jalan Abimanyu 3, RT 01/RW 02, Gelangan, Magelang Tengah, Kota Magelang
# Jenis Kelamin: Perempuan
# Hobi: Menulis, Menonton film, Membaca, Jalan-jalan menyusuri gang-gang cantik
